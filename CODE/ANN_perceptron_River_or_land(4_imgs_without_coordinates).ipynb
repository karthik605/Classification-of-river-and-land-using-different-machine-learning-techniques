# %%
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image1 = Image.open('1.gif')
image1 = image1.resize((512, 512))
array1 = np.array(image1)
# Out:
# array([[ 9,  9,  6, ...,  9,  9,  9],
#        [ 9, 10,  9, ..., 12,  9,  9],
#        [ 9, 11,  7, ..., 10,  8,  8],
#        ...,
#        [ 7,  6,  6, ...,  6,  7,  5],
#        [ 8,  7,  8, ...,  6,  7,  5],
#        [ 9, 10, 10, ...,  6,  6,  5]], dtype=uint8)

# %%
image2 = Image.open('2.gif')
image2 = image2.resize((512, 512))
array2 = np.array(image2)
# Out:
# array([[11, 11,  9, ..., 11, 12, 12],
#        [10, 11, 11, ..., 14, 12, 12],
#        [10, 11, 10, ..., 12, 11, 12],
#        ...,
#        [ 9,  8,  7, ...,  6,  7,  7],
#        [ 9,  8,  9, ...,  7,  7,  6],
#        [10, 11, 12, ...,  6,  7,  6]], dtype=uint8)

# %%
image3 = Image.open('3.gif')
image3 = image3.resize((512, 512))
array3 = np.array(image3)
# Out:
# 18

# %%
image4 = Image.open('4.gif')
image4 = image4.resize((512, 512))
array4 = np.array(image4)
# Out:
# [[28 27 26 ... 18 19 19]
#  [29 29 28 ... 19 19 19]
#  [29 29 27 ... 21 19 19]
#  ...
#  [19 17 19 ...  8 13 10]
#  [23 19 21 ...  9 17  8]
#  [25 24 24 ... 11 17  8]]

# %%
river_pts=pd.read_excel('data_river.xlsx',header=None)
river_pts=np.resize(river_pts,(2,50))
river_pts=river_pts.transpose()
for i in range(50):
  river_pts[i][:2]-= 1
river_points=np.array(river_pts)

# %%
nonriver_points = pd.read_excel('data_nonriver.xlsx',header=None)
nonriver_points = np.resize(nonriver_points,(2,100))
nonriver_points = nonriver_points.transpose()
for i in range(100):
  nonriver_points[i][:2]-= 1
nonriver_points = np.array(nonriver_points)
total_data = np.vstack((nonriver_points,river_points))
cases = [0 if i<=99 else 1 for i in range(150)]

# %%
input_data = []
for x,y in total_data:
  input_data.append([array1[x][y],array2[x][y],array3[x][y],array4[x][y]])
input_data = np.array(input_data)
row,col = input_data.shape
print(row,col)
# Out:
# 150 4

# %%
learn_rate = 0.01
iterations = 1000
w = np.zeros((col),dtype=float)
b = 0
cases = np.where(np.array(cases) <= 0, -1, 1)
for _ in range(iterations):
  for ind,x in enumerate(input_data):
    linear_output = np.dot(x,w) + b
    y_predicted = np.where(linear_output > 0,1,-1)

    update = learn_rate*(cases[ind]-y_predicted)
    w += update*x
    b += update
print("weight : ",w,"bias : ",b)
output_mat=np.zeros((512,512))
l=[]
for i in range(512):
  for j in range(512):
    l=np.array([array1[i][j],array2[i][j],array3[i][j],array4[i][j]])
    if(np.dot(l,w)-b)>=1:
      output_mat[i][j]=255
# Out:
# weight :  [ 6.16 -2.92  3.38 -5.54] bias :  -10.179999999999872

# %%
plt.imshow(output_mat,cmap='gray')
